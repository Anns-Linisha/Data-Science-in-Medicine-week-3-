# %% [markdown]
# #Logistic regression of diabetic data.csv

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('diabetic_data.csv')
df1 = df.select_dtypes(include=['number'])

X= df1.drop('admission_source_id' , axis=1)
y = df1['admission_source_id']

X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 , test_size=0.2)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression(max_iter=100000)

model.fit(X_train,y_train)

y_pred = model.predict(X_test)

print("Accuracy score is :" , accuracy_score(y_test,y_pred))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test , y_pred)

sns.heatmap(cm , fmt='d' , annot=True , cmap='Greens')

plt.title('Confusion matrix of outcome using Logistic Regression')
plt.xlabel("Predicted value")
plt.ylabel("Actual value")
plt.figure(figsize=(10,10))

plt.show()
# Out:
# Accuracy score is : 0.5651960302643215

# %% [markdown]
# #Logistic Regression for discharge_disposition_id

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('diabetic_data.csv')
df1 = df.select_dtypes(include=['number'])

X= df1.drop('discharge_disposition_id' , axis=1)
y = df1['discharge_disposition_id']

X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 , test_size=0.2)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression(max_iter=100000)

model.fit(X_train,y_train)

y_pred = model.predict(X_test)

print("Accuracy score is :" , accuracy_score(y_test,y_pred))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test , y_pred)

sns.heatmap(cm , fmt='d' , annot=True , cmap='Greens')

plt.title('Confusion matrix of outcome using Logistic Regression')
plt.xlabel("Predicted value")
plt.ylabel("Actual value")
plt.figure(figsize=(10,10))

plt.show()
# Out:
# Accuracy score is : 0.5869116635550752

# %% [markdown]
# number_diagnoses

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('diabetic_data.csv')
df1 = df.select_dtypes(include=['number'])

X= df1.drop('number_diagnoses' , axis=1)
y = df1['number_diagnoses']

X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 , test_size=0.2)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression(max_iter=100000)

model.fit(X_train,y_train)

y_pred = model.predict(X_test)

print("Accuracy score is :" , accuracy_score(y_test,y_pred))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test , y_pred)

sns.heatmap(cm , fmt='d' , annot=True , cmap='Greens')

plt.title('Confusion matrix of outcome using Logistic Regression')
plt.xlabel("Predicted value")
plt.ylabel("Actual value")
plt.figure(figsize=(10,10))

plt.show()
# Out:
# Accuracy score is : 0.48653827257541515

# %% [markdown]
# num_procedures

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('diabetic_data.csv')
df1 = df.select_dtypes(include=['number'])

X= df1.drop('num_procedures' , axis=1)
y = df1['num_procedures']

X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 , test_size=0.2)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression(max_iter=100000)

model.fit(X_train,y_train)

y_pred = model.predict(X_test)

print("Accuracy score is :" , accuracy_score(y_test,y_pred))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test , y_pred)

sns.heatmap(cm , fmt='d' , annot=True , cmap='Greens')

plt.title('Confusion matrix of num of procedures using Logistic Regression')
plt.xlabel("Predicted value")
plt.ylabel("Actual value")
plt.figure(figsize=(10,10))

plt.show()
# Out:
# Accuracy score is : 0.45706003733909795

# %% [markdown]
# #decision tree

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('diabetic_data.csv')
df1 = df.select_dtypes(include=['number'])

X = df1.drop('num_procedures' , axis=1)
y = df1['num_procedures']

X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 , test_size=0.2)

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model = DecisionTreeClassifier(max_depth=8 , random_state=42)
model.fit(X_train , y_train )
y_pred = model.predict(X_test)

print("Accuracy score : " , accuracy_score(y_test , y_pred))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test , y_pred)
sns.heatmap(cm , fmt='d' , annot=True , cmap='Reds')
plt.title("Confusion matrix of num of procedures using decision tree")
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.show()
# Out:
# Accuracy score :  0.4909108774688022

# %% [markdown]
# #KNN

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('diabetic_data.csv')
df1 = df.select_dtypes(include=['number'])

X = df1.drop('num_procedures' , axis=1)
y = df1['num_procedures']

X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 , test_size=0.2)

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train , y_train )
y_pred = model.predict(X_test)

print("Accuracy score : " , accuracy_score(y_test , y_pred))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test , y_pred)
sns.heatmap(cm , fmt='d' , annot=True , cmap='Purples')
plt.title("Confusion matrix of outcome using KNN alg")
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.show()
# Out:
# Accuracy score :  0.39014444335265797

# %% [markdown]
# #random forest

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('diabetic_data.csv')
df1 = df.select_dtypes(include=['number'])

X = df1.drop('num_procedures' , axis=1)
y = df1['num_procedures']

X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 , test_size=0.2)

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier(max_depth=8 , random_state=42)
model.fit(X_train , y_train )
y_pred = model.predict(X_test)

print("Accuracy score : " , accuracy_score(y_test , y_pred))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test , y_pred)
sns.heatmap(cm , fmt='d' , annot=True , cmap='cool')
plt.title("Confusion matrix of outcome using random forest")
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.show()
# Out:
# Accuracy score :  0.4964134813795814

# %% [markdown]
# number_outpatient

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('diabetic_data.csv')
df1 = df.select_dtypes(include=['number'])

X= df1.drop('number_outpatient' , axis=1)
y = df1['number_outpatient']

X_train , X_test , y_train , y_test = train_test_split(X , y , random_state=42 , test_size=0.2)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression(max_iter=1000)

model.fit(X_train,y_train)

y_pred = model.predict(X_test)

print("Accuracy score is :" , accuracy_score(y_test,y_pred))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test , y_pred)

sns.heatmap(cm , fmt='d' , annot=True , cmap='Greens')

plt.title('Confusion matrix of outcome using Logistic Regression')
plt.xlabel("Predicted value")
plt.ylabel("Actual value")
plt.figure(figsize=(10,10))

plt.show()
# Out:
# Accuracy score is : 0.8355605777734106
